# %%
Generate Cities List
In [1]:
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import logging
import json

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
# Output File (CSV)
output_data_file = "output_data/cities.csv"

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
In [2]:
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# %%
# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# %%
# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# %%
# Print the city count to confirm sufficient count
len(cities)
Out[2]:
618
Perform API Calls
Perform a weather check on each city using a series of successive API calls.
Include a print log of each city as it'sbeing processed (with the city number and city name).
In [3]:
# Perform a weather check on each city using a series of successful API calls.
url = "http://api.openweathermap.org/data/2.5/weather?"

# Create list of variable values
city_name1 = []
cloudy_percent1 = []
country_name1 = []
date1 = []
humidity1 = []
lat1 = []
lng1 = []
max_temp1 = []
wind_speed1 = []

#record number
n = 0

#begin printing log of each city as it's being processed
print("Beginning Data Retrieval")
print("---------------------------")

# %%
# Build query URL
for city in cities:
    
    #api request for each city
    response = requests.get(url + "appid=" + api_key + "&units=IMPERIAL" + "metric" + "&q=" + city).json()
    
    #assign variable to variable name
    if response['cod'] == 200:
        n += 1
        city_name = response['name']
        cloudy_percent = response['clouds']['all']
        country_name = response['sys']['country']
        date = response['dt']
        humidity = response['main']['humidity']
        lat = response['coord']['lat']
        lng = response['coord']['lon']
        max_temp = response['main']['temp_max']
        wind_speed = response['wind']['speed']
        
        #print log for each city that is available
        print(f"Processing Record {n} of Set 1 | {city_name}")
        
    elif response['cod'] != 200:
        #print log for each city that's not available
        print("City not found. Skipping...")

    #append variable values to lists
    city_name1.append(city_name)
    cloudy_percent1.append(cloudy_percent)
    country_name1.append(country_name)
    date1.append(date)
    humidity1.append(humidity)
    lat1.append(lat)
    lng1.append(lng)
    max_temp1.append(max_temp)
    wind_speed1.append(wind_speed)

# %%
print("---------------------------")
print("Data Retrieval Complete")
print("---------------------------")
Beginning Data Retrieval
---------------------------
Processing Record 1 of Set 1 | Hobart
Processing Record 2 of Set 1 | Longyearbyen
Processing Record 3 of Set 1 | San Patricio
Processing Record 4 of Set 1 | Hithadhoo
Processing Record 5 of Set 1 | Yatou
Processing Record 6 of Set 1 | Lebu
Processing Record 7 of Set 1 | Busselton
Processing Record 8 of Set 1 | Shingu
City not found. Skipping...
Processing Record 9 of Set 1 | Punta Arenas
Processing Record 10 of Set 1 | Ushuaia
Processing Record 11 of Set 1 | Bonavista
Processing Record 12 of Set 1 | Butaritari
City not found. Skipping...
Processing Record 13 of Set 1 | Sheopur
Processing Record 14 of Set 1 | Severo-Kurilsk
Processing Record 15 of Set 1 | Witu
Processing Record 16 of Set 1 | Lake City
Processing Record 17 of Set 1 | Aldan
Processing Record 18 of Set 1 | Chuy
Processing Record 19 of Set 1 | Colesberg
Processing Record 20 of Set 1 | Khatanga
Processing Record 21 of Set 1 | Leningradskiy
Processing Record 22 of Set 1 | Barrow
City not found. Skipping...
Processing Record 23 of Set 1 | Saskylakh
Processing Record 24 of Set 1 | Havelock
Processing Record 25 of Set 1 | Nikolskoye
Processing Record 26 of Set 1 | Fortuna
Processing Record 27 of Set 1 | Murovane
City not found. Skipping...
Processing Record 28 of Set 1 | Nikolayevka
Processing Record 29 of Set 1 | Zhezkazgan
Processing Record 30 of Set 1 | Bredasdorp
City not found. Skipping...
Processing Record 31 of Set 1 | Ruston
Processing Record 32 of Set 1 | Mahebourg
Processing Record 33 of Set 1 | Takayama
Processing Record 34 of Set 1 | Ulladulla
Processing Record 35 of Set 1 | Le Port
Processing Record 36 of Set 1 | San Rafael
Processing Record 37 of Set 1 | Lagoa
Processing Record 38 of Set 1 | Morondava
Processing Record 39 of Set 1 | Chauk
Processing Record 40 of Set 1 | Puerto Ayora
Processing Record 41 of Set 1 | Ferme-Neuve
Processing Record 42 of Set 1 | Chifeng
Processing Record 43 of Set 1 | Tuatapere
Processing Record 44 of Set 1 | Karratha
Processing Record 45 of Set 1 | Eureka
Processing Record 46 of Set 1 | Xining
Processing Record 47 of Set 1 | Hermanus
Processing Record 48 of Set 1 | Atuona
Processing Record 49 of Set 1 | Faanui
Processing Record 50 of Set 1 | Fort Frances
Processing Record 51 of Set 1 | Cairns
Processing Record 52 of Set 1 | Mogadishu
Processing Record 53 of Set 1 | Ribeira Grande
Processing Record 54 of Set 1 | Nanortalik
Processing Record 55 of Set 1 | Torbay
Processing Record 56 of Set 1 | Vaini
Processing Record 57 of Set 1 | Flinders
Processing Record 58 of Set 1 | Albany
Processing Record 59 of Set 1 | Rikitea
City not found. Skipping...
City not found. Skipping...
Processing Record 60 of Set 1 | Cape Town
Processing Record 61 of Set 1 | Whitehorse
Processing Record 62 of Set 1 | Tuktoyaktuk
Processing Record 63 of Set 1 | Nanlong
City not found. Skipping...
Processing Record 64 of Set 1 | Sunndalsora
Processing Record 65 of Set 1 | Vestmannaeyjar
Processing Record 66 of Set 1 | Aras
City not found. Skipping...
Processing Record 67 of Set 1 | Kungurtug
Processing Record 68 of Set 1 | Rognan
City not found. Skipping...
Processing Record 69 of Set 1 | Lyubim
Processing Record 70 of Set 1 | Little Current
Processing Record 71 of Set 1 | Taoudenni
Processing Record 72 of Set 1 | Caucaia
Processing Record 73 of Set 1 | Haimen
Processing Record 74 of Set 1 | Cortes
Processing Record 75 of Set 1 | New Norfolk
Processing Record 76 of Set 1 | Sabile
Processing Record 77 of Set 1 | Raudeberg
Processing Record 78 of Set 1 | Kantang
Processing Record 79 of Set 1 | Isangel
Processing Record 80 of Set 1 | Marsh Harbour
Processing Record 81 of Set 1 | Dvinskoy
Processing Record 82 of Set 1 | Coahuayana
Processing Record 83 of Set 1 | Ruteng
Processing Record 84 of Set 1 | Paoua
Processing Record 85 of Set 1 | Okhotsk
Processing Record 86 of Set 1 | Nelson Bay
Processing Record 87 of Set 1 | Quatre Cocos
Processing Record 88 of Set 1 | Derac
Processing Record 89 of Set 1 | Dikson
Processing Record 90 of Set 1 | Rocha
City not found. Skipping...
Processing Record 91 of Set 1 | Poum
Processing Record 92 of Set 1 | Talnakh
Processing Record 93 of Set 1 | Andalan
Processing Record 94 of Set 1 | Harper
City not found. Skipping...
City not found. Skipping...
Processing Record 95 of Set 1 | Kapaa
Processing Record 96 of Set 1 | Maldonado
Processing Record 97 of Set 1 | Baie-Comeau
Processing Record 98 of Set 1 | Santa Rosa
Processing Record 99 of Set 1 | Mackay
Processing Record 100 of Set 1 | Codrington
Processing Record 101 of Set 1 | Yuryuzan
City not found. Skipping...
Processing Record 102 of Set 1 | Victoria
Processing Record 103 of Set 1 | Montecorvino Rovella
Processing Record 104 of Set 1 | Rafaela
Processing Record 105 of Set 1 | Oktyabrskiy
Processing Record 106 of Set 1 | Saint-Philippe
Processing Record 107 of Set 1 | Sao Filipe
Processing Record 108 of Set 1 | Hargeysa
Processing Record 109 of Set 1 | Acandi
Processing Record 110 of Set 1 | Mataura
Processing Record 111 of Set 1 | Hilo
Processing Record 112 of Set 1 | Berlevag
Processing Record 113 of Set 1 | Port Hedland
Processing Record 114 of Set 1 | Saint-Pierre
Processing Record 115 of Set 1 | Auki
Processing Record 116 of Set 1 | Tiksi
Processing Record 117 of Set 1 | Lins
Processing Record 118 of Set 1 | Airai
City not found. Skipping...
City not found. Skipping...
Processing Record 119 of Set 1 | Katsuura
Processing Record 120 of Set 1 | Ancud
Processing Record 121 of Set 1 | Goba
Processing Record 122 of Set 1 | Qaanaaq
Processing Record 123 of Set 1 | Conakry
Processing Record 124 of Set 1 | Port Alfred
Processing Record 125 of Set 1 | Avarua
Processing Record 126 of Set 1 | Sidi Ali
Processing Record 127 of Set 1 | Biak
Processing Record 128 of Set 1 | Jamestown
Processing Record 129 of Set 1 | Gobabis
Processing Record 130 of Set 1 | Fontenay-le-Comte
Processing Record 131 of Set 1 | Ilulissat
City not found. Skipping...
Processing Record 132 of Set 1 | Yellowknife
Processing Record 133 of Set 1 | Mehamn
City not found. Skipping...
Processing Record 134 of Set 1 | Arraial do Cabo
Processing Record 135 of Set 1 | Kastoria
Processing Record 136 of Set 1 | Ereymentau
Processing Record 137 of Set 1 | Balaipungut
Processing Record 138 of Set 1 | Walvis Bay
Processing Record 139 of Set 1 | Lavrentiya
Processing Record 140 of Set 1 | Mutis
Processing Record 141 of Set 1 | Phuket
Processing Record 142 of Set 1 | Kansanshi
Processing Record 143 of Set 1 | Alice Springs
Processing Record 144 of Set 1 | La Peca
Processing Record 145 of Set 1 | Zheleznodorozhnyy
Processing Record 146 of Set 1 | Chato
Processing Record 147 of Set 1 | Souillac
Processing Record 148 of Set 1 | Tasiilaq
Processing Record 149 of Set 1 | Belaya Gora
Processing Record 150 of Set 1 | San Lorenzo
Processing Record 151 of Set 1 | Verkhnyaya Balkariya
Processing Record 152 of Set 1 | Carutapera
Processing Record 153 of Set 1 | Luderitz
City not found. Skipping...
Processing Record 154 of Set 1 | Bluff
Processing Record 155 of Set 1 | East London
Processing Record 156 of Set 1 | Mar del Plata
Processing Record 157 of Set 1 | Batemans Bay
Processing Record 158 of Set 1 | Thompson
Processing Record 159 of Set 1 | Turbat
Processing Record 160 of Set 1 | Kaitangata
Processing Record 161 of Set 1 | Hearst
City not found. Skipping...
City not found. Skipping...
Processing Record 162 of Set 1 | Westport
Processing Record 163 of Set 1 | Arenapolis
Processing Record 164 of Set 1 | Makakilo City
Processing Record 165 of Set 1 | Narsaq
Processing Record 166 of Set 1 | Bambous Virieux
Processing Record 167 of Set 1 | Bandarbeyla
Processing Record 168 of Set 1 | Rundu
Processing Record 169 of Set 1 | San Quintin
Processing Record 170 of Set 1 | Norman Wells
City not found. Skipping...
Processing Record 171 of Set 1 | Banjar
Processing Record 172 of Set 1 | Osa
Processing Record 173 of Set 1 | Beringovskiy
Processing Record 174 of Set 1 | Kawalu
Processing Record 175 of Set 1 | Pevek
Processing Record 176 of Set 1 | Vallenar
City not found. Skipping...
Processing Record 177 of Set 1 | Cidreira
Processing Record 178 of Set 1 | Waingapu
Processing Record 179 of Set 1 | Bathsheba
Processing Record 180 of Set 1 | Castro
Processing Record 181 of Set 1 | Lata
City not found. Skipping...
Processing Record 182 of Set 1 | Yulara
Processing Record 183 of Set 1 | Alofi
Processing Record 184 of Set 1 | Dingle
Processing Record 185 of Set 1 | Iqaluit
Processing Record 186 of Set 1 | Viedma
Processing Record 187 of Set 1 | Sydney Mines
Processing Record 188 of Set 1 | Port-Cartier
City not found. Skipping...
City not found. Skipping...
Processing Record 189 of Set 1 | Kachiry
City not found. Skipping...
Processing Record 190 of Set 1 | Loa Janan
City not found. Skipping...
Processing Record 191 of Set 1 | Honiara
City not found. Skipping...
City not found. Skipping...
Processing Record 192 of Set 1 | Osmanabad
Processing Record 193 of Set 1 | Vila Franca do Campo
Processing Record 194 of Set 1 | Grindavik
Processing Record 195 of Set 1 | Biltine
Processing Record 196 of Set 1 | Sitka
Processing Record 197 of Set 1 | Te Anau
Processing Record 198 of Set 1 | Pinawa
Processing Record 199 of Set 1 | Srednekolymsk
Processing Record 200 of Set 1 | Copiapo
Processing Record 201 of Set 1 | Altay
Processing Record 202 of Set 1 | Rabo de Peixe
Processing Record 203 of Set 1 | Solnechnyy
Processing Record 204 of Set 1 | Penzance
Processing Record 205 of Set 1 | Sechura
Processing Record 206 of Set 1 | Namibe
Processing Record 207 of Set 1 | Iralaya
Processing Record 208 of Set 1 | Kodiak
Processing Record 209 of Set 1 | Portland
Processing Record 210 of Set 1 | Jizan
City not found. Skipping...
City not found. Skipping...
Processing Record 211 of Set 1 | Oum Hadjer
Processing Record 212 of Set 1 | Carnarvon
Processing Record 213 of Set 1 | Adrar
Processing Record 214 of Set 1 | Lasem
Processing Record 215 of Set 1 | Kulhudhuffushi
Processing Record 216 of Set 1 | Lazarev
Processing Record 217 of Set 1 | Klaksvik
Processing Record 218 of Set 1 | Esperance
Processing Record 219 of Set 1 | Cooma
Processing Record 220 of Set 1 | Bethel
Processing Record 221 of Set 1 | Kudahuvadhoo
Processing Record 222 of Set 1 | Sao Felix do Xingu
City not found. Skipping...
Processing Record 223 of Set 1 | Shelburne
Processing Record 224 of Set 1 | Hamilton
Processing Record 225 of Set 1 | Mulchen
Processing Record 226 of Set 1 | Beloha
Processing Record 227 of Set 1 | Upernavik
Processing Record 228 of Set 1 | Port Elizabeth
Processing Record 229 of Set 1 | Shache
Processing Record 230 of Set 1 | Mount Gambier
Processing Record 231 of Set 1 | Langxiang
Processing Record 232 of Set 1 | Nishihara
Processing Record 233 of Set 1 | Tongchuan
Processing Record 234 of Set 1 | Provideniya
Processing Record 235 of Set 1 | Sioux Lookout
Processing Record 236 of Set 1 | Huarmey
Processing Record 237 of Set 1 | Road Town
Processing Record 238 of Set 1 | Carauari
Processing Record 239 of Set 1 | Kahului
Processing Record 240 of Set 1 | Villarrobledo
Processing Record 241 of Set 1 | Kaduqli
Processing Record 242 of Set 1 | Atasu
Processing Record 243 of Set 1 | Campoverde
Processing Record 244 of Set 1 | Novy Bydzov
Processing Record 245 of Set 1 | Tiznit
Processing Record 246 of Set 1 | Launceston
Processing Record 247 of Set 1 | Ulsteinvik
Processing Record 248 of Set 1 | Ayan
Processing Record 249 of Set 1 | Gombong
Processing Record 250 of Set 1 | Lorengau
Processing Record 251 of Set 1 | Asyut
Processing Record 252 of Set 1 | Georgetown
City not found. Skipping...
Processing Record 253 of Set 1 | San Cristobal
Processing Record 254 of Set 1 | Boston
Processing Record 255 of Set 1 | Stephenville
Processing Record 256 of Set 1 | Keti Bandar
Processing Record 257 of Set 1 | Kalmunai
Processing Record 258 of Set 1 | Arsikere
Processing Record 259 of Set 1 | Constitucion
Processing Record 260 of Set 1 | Diplo
City not found. Skipping...
Processing Record 261 of Set 1 | Burnie
Processing Record 262 of Set 1 | Naranjal
Processing Record 263 of Set 1 | Salamiyah
Processing Record 264 of Set 1 | Lagos
Processing Record 265 of Set 1 | Tairua
Processing Record 266 of Set 1 | Ahipara
Processing Record 267 of Set 1 | Ariquemes
Processing Record 268 of Set 1 | Bjornevatn
City not found. Skipping...
Processing Record 269 of Set 1 | Paamiut
City not found. Skipping...
Processing Record 270 of Set 1 | Rio Gallegos
Processing Record 271 of Set 1 | Cabedelo
Processing Record 272 of Set 1 | Lincoln
Processing Record 273 of Set 1 | Vao
Processing Record 274 of Set 1 | Le Vauclin
Processing Record 275 of Set 1 | Champasak
Processing Record 276 of Set 1 | Chokurdakh
Processing Record 277 of Set 1 | Arman
Processing Record 278 of Set 1 | Saint Anthony
Processing Record 279 of Set 1 | Cherskiy
Processing Record 280 of Set 1 | Saint George
Processing Record 281 of Set 1 | Bolshevik
Processing Record 282 of Set 1 | Astana
Processing Record 283 of Set 1 | Dunedin
Processing Record 284 of Set 1 | Hovd
Processing Record 285 of Set 1 | Tongren
Processing Record 286 of Set 1 | Wrexham
Processing Record 287 of Set 1 | Papar
City not found. Skipping...
Processing Record 288 of Set 1 | Znin
Processing Record 289 of Set 1 | Balakhninskiy
Processing Record 290 of Set 1 | Waddan
Processing Record 291 of Set 1 | Tonstad
Processing Record 292 of Set 1 | Tahoua
Processing Record 293 of Set 1 | Hegang
Processing Record 294 of Set 1 | Yumaguzino
Processing Record 295 of Set 1 | Pangai
Processing Record 296 of Set 1 | Pauini
Processing Record 297 of Set 1 | Tumsar
Processing Record 298 of Set 1 | Hokitika
Processing Record 299 of Set 1 | Almeirim
Processing Record 300 of Set 1 | Litovko
Processing Record 301 of Set 1 | Sao Jose da Coroa Grande
Processing Record 302 of Set 1 | San Ignacio
Processing Record 303 of Set 1 | Caidian
Processing Record 304 of Set 1 | Langham
Processing Record 305 of Set 1 | Kaeo
Processing Record 306 of Set 1 | Kavaratti
Processing Record 307 of Set 1 | Cape Canaveral
Processing Record 308 of Set 1 | Magdalena
Processing Record 309 of Set 1 | Westlock
Processing Record 310 of Set 1 | Ko Samui
Processing Record 311 of Set 1 | Iquique
Processing Record 312 of Set 1 | Ponta do Sol
Processing Record 313 of Set 1 | Yaviza
Processing Record 314 of Set 1 | Barmer
Processing Record 315 of Set 1 | Dolgoye
Processing Record 316 of Set 1 | Apatity
Processing Record 317 of Set 1 | Komsomolskiy
Processing Record 318 of Set 1 | Belmonte
Processing Record 319 of Set 1 | Westerland
Processing Record 320 of Set 1 | Savannah Bight
Processing Record 321 of Set 1 | Peterhead
Processing Record 322 of Set 1 | Gamba
Processing Record 323 of Set 1 | Alta Floresta
Processing Record 324 of Set 1 | Privolzhskiy
Processing Record 325 of Set 1 | Turukhansk
Processing Record 326 of Set 1 | Mezen
Processing Record 327 of Set 1 | Forbes
Processing Record 328 of Set 1 | Khani
Processing Record 329 of Set 1 | Maragogi
Processing Record 330 of Set 1 | Zheshart
Processing Record 331 of Set 1 | Fairbanks
Processing Record 332 of Set 1 | Narasannapeta
Processing Record 333 of Set 1 | Lesnoy
Processing Record 334 of Set 1 | Bonfim
Processing Record 335 of Set 1 | Sulangan
Processing Record 336 of Set 1 | Motygino
Processing Record 337 of Set 1 | Carmo do Rio Verde
Processing Record 338 of Set 1 | Santa Rita
Processing Record 339 of Set 1 | Cockburn Town
Processing Record 340 of Set 1 | Jalu
Processing Record 341 of Set 1 | Nome
City not found. Skipping...
City not found. Skipping...
Processing Record 342 of Set 1 | Watertown
Processing Record 343 of Set 1 | Ponta Delgada
Processing Record 344 of Set 1 | Nantucket
Processing Record 345 of Set 1 | Daru
Processing Record 346 of Set 1 | Adilcevaz
Processing Record 347 of Set 1 | Bulgan
Processing Record 348 of Set 1 | Tlalmanalco
Processing Record 349 of Set 1 | Tymovskoye
Processing Record 350 of Set 1 | General Roca
Processing Record 351 of Set 1 | Tamworth
Processing Record 352 of Set 1 | Japura
Processing Record 353 of Set 1 | Saldanha
Processing Record 354 of Set 1 | Tarko-Sale
Processing Record 355 of Set 1 | Aripuana
Processing Record 356 of Set 1 | Salalah
Processing Record 357 of Set 1 | Doha
City not found. Skipping...
Processing Record 358 of Set 1 | Erenhot
City not found. Skipping...
Processing Record 359 of Set 1 | Kijang
Processing Record 360 of Set 1 | Bud
Processing Record 361 of Set 1 | Wajima
Processing Record 362 of Set 1 | Mayor Pablo Lagerenza
Processing Record 363 of Set 1 | Meadow Lake
Processing Record 364 of Set 1 | Rantepao
City not found. Skipping...
Processing Record 365 of Set 1 | Coquimbo
Processing Record 366 of Set 1 | Teacapan
Processing Record 367 of Set 1 | Mancora
Processing Record 368 of Set 1 | Puntarenas
Processing Record 369 of Set 1 | Maketu
Processing Record 370 of Set 1 | Kargil
Processing Record 371 of Set 1 | Aklavik
Processing Record 372 of Set 1 | Umea
Processing Record 373 of Set 1 | Santa Cruz Cabralia
Processing Record 374 of Set 1 | Vung Tau
Processing Record 375 of Set 1 | Haines Junction
Processing Record 376 of Set 1 | Tete
Processing Record 377 of Set 1 | Shenjiamen
Processing Record 378 of Set 1 | Meulaboh
Processing Record 379 of Set 1 | Kabanjahe
Processing Record 380 of Set 1 | Trelew
Processing Record 381 of Set 1 | Faya
Processing Record 382 of Set 1 | Comodoro Rivadavia
Processing Record 383 of Set 1 | Sao Joao da Barra
Processing Record 384 of Set 1 | Mangan
Processing Record 385 of Set 1 | Ixtapa
Processing Record 386 of Set 1 | Kanniyakumari
Processing Record 387 of Set 1 | Mayo
Processing Record 388 of Set 1 | Warrnambool
Processing Record 389 of Set 1 | La Palma
Processing Record 390 of Set 1 | Matagami
Processing Record 391 of Set 1 | Bambanglipuro
City not found. Skipping...
Processing Record 392 of Set 1 | Oranjemund
Processing Record 393 of Set 1 | Baruun-Urt
Processing Record 394 of Set 1 | Huanan
Processing Record 395 of Set 1 | Fayetteville
Processing Record 396 of Set 1 | Gat
Processing Record 397 of Set 1 | Sahuaripa
Processing Record 398 of Set 1 | Charters Towers
City not found. Skipping...
Processing Record 399 of Set 1 | Horsham
Processing Record 400 of Set 1 | Yarada
Processing Record 401 of Set 1 | Vanimo
Processing Record 402 of Set 1 | Tezu
City not found. Skipping...
Processing Record 403 of Set 1 | Quelimane
Processing Record 404 of Set 1 | Port Lincoln
Processing Record 405 of Set 1 | Urusha
Processing Record 406 of Set 1 | Voi
Processing Record 407 of Set 1 | Makat
Processing Record 408 of Set 1 | Itarema
Processing Record 409 of Set 1 | Hasaki
Processing Record 410 of Set 1 | Oistins
Processing Record 411 of Set 1 | Knysna
Processing Record 412 of Set 1 | Ust-Kulom
Processing Record 413 of Set 1 | Beyneu
Processing Record 414 of Set 1 | Husavik
Processing Record 415 of Set 1 | Iquitos
City not found. Skipping...
Processing Record 416 of Set 1 | Bonthe
Processing Record 417 of Set 1 | Hobyo
Processing Record 418 of Set 1 | Nipawin
City not found. Skipping...
Processing Record 419 of Set 1 | Acapulco
Processing Record 420 of Set 1 | Baghdad
Processing Record 421 of Set 1 | Sinjar
Processing Record 422 of Set 1 | San Pedro
Processing Record 423 of Set 1 | Mildura
Processing Record 424 of Set 1 | Kharp
Processing Record 425 of Set 1 | Laguna
Processing Record 426 of Set 1 | Hofn
Processing Record 427 of Set 1 | Manhuacu
Processing Record 428 of Set 1 | Kumla
Processing Record 429 of Set 1 | Mana
Processing Record 430 of Set 1 | Poltavka
Processing Record 431 of Set 1 | Kultuk
Processing Record 432 of Set 1 | Ust-Maya
Processing Record 433 of Set 1 | Tucumcari
Processing Record 434 of Set 1 | Yerbogachen
Processing Record 435 of Set 1 | Puerto Ayacucho
Processing Record 436 of Set 1 | San Jose
Processing Record 437 of Set 1 | Vostok
Processing Record 438 of Set 1 | Denpasar
Processing Record 439 of Set 1 | Avera
Processing Record 440 of Set 1 | Alekseyevsk
Processing Record 441 of Set 1 | Cap-aux-Meules
Processing Record 442 of Set 1 | Hami
Processing Record 443 of Set 1 | Severo-Yeniseyskiy
Processing Record 444 of Set 1 | Camacha
City not found. Skipping...
Processing Record 445 of Set 1 | Krivosheino
Processing Record 446 of Set 1 | Fare
Processing Record 447 of Set 1 | Jutai
Processing Record 448 of Set 1 | Zhigansk
Processing Record 449 of Set 1 | Pouebo
Processing Record 450 of Set 1 | Manokwari
Processing Record 451 of Set 1 | Canton
Processing Record 452 of Set 1 | Inhambane
Processing Record 453 of Set 1 | Sayyan
Processing Record 454 of Set 1 | Taltal
Processing Record 455 of Set 1 | Tual
Processing Record 456 of Set 1 | Anadyr
Processing Record 457 of Set 1 | La Ronge
Processing Record 458 of Set 1 | Yinchuan
Processing Record 459 of Set 1 | San Policarpo
Processing Record 460 of Set 1 | College
Processing Record 461 of Set 1 | Tessalit
Processing Record 462 of Set 1 | Baykit
Processing Record 463 of Set 1 | Richards Bay
Processing Record 464 of Set 1 | Kamariotissa
Processing Record 465 of Set 1 | Singkang
Processing Record 466 of Set 1 | Jackson
Processing Record 467 of Set 1 | Port Macquarie
Processing Record 468 of Set 1 | Lompoc
Processing Record 469 of Set 1 | Buala
Processing Record 470 of Set 1 | Heihe
Processing Record 471 of Set 1 | Sembakung
Processing Record 472 of Set 1 | Kununurra
Processing Record 473 of Set 1 | Mandera
Processing Record 474 of Set 1 | Goderich
Processing Record 475 of Set 1 | Valle de Allende
City not found. Skipping...
Processing Record 476 of Set 1 | Kralendijk
Processing Record 477 of Set 1 | Gulu
Processing Record 478 of Set 1 | Puerto del Rosario
Processing Record 479 of Set 1 | Tocopilla
City not found. Skipping...
Processing Record 480 of Set 1 | Broome
Processing Record 481 of Set 1 | Praia da Vitoria
Processing Record 482 of Set 1 | Erbaa
Processing Record 483 of Set 1 | Kirakira
Processing Record 484 of Set 1 | Dudinka
Processing Record 485 of Set 1 | Hellvik
Processing Record 486 of Set 1 | Santa Maria
City not found. Skipping...
Processing Record 487 of Set 1 | Baherden
Processing Record 488 of Set 1 | Gunjur
Processing Record 489 of Set 1 | Bilma
Processing Record 490 of Set 1 | Novovarshavka
Processing Record 491 of Set 1 | Homer
Processing Record 492 of Set 1 | Port-Gentil
Processing Record 493 of Set 1 | Rapid Valley
Processing Record 494 of Set 1 | Luanda
Processing Record 495 of Set 1 | Margate
Processing Record 496 of Set 1 | Ivankiv
Processing Record 497 of Set 1 | Druzhba
Processing Record 498 of Set 1 | Victoria
Processing Record 499 of Set 1 | Puerto Leguizamo
Processing Record 500 of Set 1 | Ossora
Processing Record 501 of Set 1 | Caravelas
City not found. Skipping...
City not found. Skipping...
Processing Record 502 of Set 1 | Tateyama
Processing Record 503 of Set 1 | Senador Jose Porfirio
Processing Record 504 of Set 1 | Jambusar
City not found. Skipping...
Processing Record 505 of Set 1 | Cocobeach
Processing Record 506 of Set 1 | Kaniama
Processing Record 507 of Set 1 | King City
Processing Record 508 of Set 1 | Usinsk
Processing Record 509 of Set 1 | Deputatskiy
Processing Record 510 of Set 1 | Rameswaram
Processing Record 511 of Set 1 | Kaohsiung
Processing Record 512 of Set 1 | Bahir Dar
Processing Record 513 of Set 1 | Aksarka
Processing Record 514 of Set 1 | Hauterive
Processing Record 515 of Set 1 | Sibu
Processing Record 516 of Set 1 | Bahia de Caraquez
Processing Record 517 of Set 1 | Varberg
Processing Record 518 of Set 1 | Aswan
Processing Record 519 of Set 1 | Mahanoro
Processing Record 520 of Set 1 | Muisne
Processing Record 521 of Set 1 | Clyde River
Processing Record 522 of Set 1 | Sambava
Processing Record 523 of Set 1 | Bridgend
Processing Record 524 of Set 1 | Ravar
Processing Record 525 of Set 1 | Batagay-Alyta
Processing Record 526 of Set 1 | Nara
City not found. Skipping...
Processing Record 527 of Set 1 | Necochea
Processing Record 528 of Set 1 | Cabo San Lucas
Processing Record 529 of Set 1 | Pisco
Processing Record 530 of Set 1 | Najran
Processing Record 531 of Set 1 | Medea
Processing Record 532 of Set 1 | Diego de Almagro
Processing Record 533 of Set 1 | Pangnirtung
Processing Record 534 of Set 1 | Kalabo
Processing Record 535 of Set 1 | Cabatuan
Processing Record 536 of Set 1 | Vilhena
Processing Record 537 of Set 1 | Hendrina
Processing Record 538 of Set 1 | Ostrovnoy
Processing Record 539 of Set 1 | Nouadhibou
Processing Record 540 of Set 1 | Ust-Ilimsk
Processing Record 541 of Set 1 | Grand-Bourg
Processing Record 542 of Set 1 | Ocos
Processing Record 543 of Set 1 | Yarmouth
Processing Record 544 of Set 1 | Carbonear
Processing Record 545 of Set 1 | Lakes Entrance
Processing Record 546 of Set 1 | Aksu
Processing Record 547 of Set 1 | Chota
Processing Record 548 of Set 1 | Baixa Grande
Processing Record 549 of Set 1 | Maun
Processing Record 550 of Set 1 | Esil
Processing Record 551 of Set 1 | Jalingo
Processing Record 552 of Set 1 | Cayenne
Processing Record 553 of Set 1 | Dmitriyevskoye
Processing Record 554 of Set 1 | Sorland
Processing Record 555 of Set 1 | Sanguem
City not found. Skipping...
Processing Record 556 of Set 1 | Guane
City not found. Skipping...
Processing Record 557 of Set 1 | Stepnogorsk
Processing Record 558 of Set 1 | Presidencia Roque Saenz Pena
Processing Record 559 of Set 1 | Marsa Matruh
Processing Record 560 of Set 1 | Maniitsoq
---------------------------
Data Retrieval Complete
---------------------------
Convert Raw Data to DataFrame
Export the city data into a .csv.
Display the DataFrame
In [4]:
#create data frame
city_data = pd.DataFrame({'City': city_name1,
                          'Cloudiness': cloudy_percent1,
                          'Country': country_name1,
                          'Date': date1,
                          'Humidity': humidity1,
                          'Latitude': lat1,
                          'Longitude': lng1,
                          'Maximum Temperature': max_temp1,
                          'Wind Speed': wind_speed1})

# %%
#display first five rows
city_data.head()
Out[5]:
City	Cloudiness	Country	Date	Humidity	Latitude	Longitude	Maximum Temperature	Wind Speed
0	Hobart	20	AU	1546896600	59	-42.88	147.33	291.150	3.60
1	Longyearbyen	40	NO	1546897800	68	78.22	15.63	269.150	18.50
2	San Patricio	88	PY	1546898744	91	-26.98	-56.83	299.454	2.21
3	Hithadhoo	64	MV	1546898741	100	-0.60	73.08	300.579	3.06
4	Yatou	40	CM	1546894800	88	3.63	9.81	300.150	0.50
In [6]:
city_data.to_csv("Weather_Data.csv", index=False, header=True)
Plotting the Data
Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
Save the plotted figures as .pngs.
Latitude vs. Temperature Plot
In [15]:
plt.scatter(city_data['Latitude'],city_data['Maximum Temperature'], marker = "o",
            facecolors = "blue", edgecolors = "black", alpha = 0.25)
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature ($^\circ$F)")
plt.title('City Latitude vs. Maximum Temperature (01/07/2019)')
plt.savefig("lat_temp.png")
plt.show
Out[15]:
<function matplotlib.pyplot.show(*args, **kw)>

Latitude vs. Humidity Plot
In [16]:
plt.scatter(city_data['Latitude'],city_data['Humidity'], marker = "o",
            facecolors = "blue", edgecolors = "black", alpha = 0.25)
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title('City Latitude vs. Percent Humidity (01/07/2019)')
plt.savefig("lat_humidity.png")
plt.show
Out[16]:
<function matplotlib.pyplot.show(*args, **kw)>

Latitude vs. Cloudiness Plot
In [17]:
plt.scatter(city_data['Latitude'],city_data['Cloudiness'], marker = "o",
            facecolors = "blue", edgecolors = "black", alpha = 0.25)
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title('City Latitude vs. Percent Cloudiness (01/07/2019)')
plt.savefig("lat_cloudiness.png")
plt.show
Out[17]:
<function matplotlib.pyplot.show(*args, **kw)>

Latitude vs. Wind Speed Plot
In [18]:
plt.scatter(city_data['Latitude'],city_data['Wind Speed'], marker = "o",
            facecolors = "blue", edgecolors = "black", alpha = 0.25)
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title('City Latitude vs. Wind Speed (01/07/2019)')
plt.savefig("lat_wind.png")
plt.show
Out[18]:
<function matplotlib.pyplot.show(*args, **kw)>
